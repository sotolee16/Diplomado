# %% [markdown]
# <a href="https://colab.research.google.com/github/sotolee16/Experimento-de-dos-dados/blob/main/Tarea_Variables_Aleatorias_Continuas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Equipo 1:**
#
# - Cadena Martínez Arturo
#
# - Hernández Rivera Jesús Iván
#
# - López Camacho Donovan Uriel
#
# - Martínez Martínez Fatima Jakelín
#
# - Soto Lee Héctor Emilio

# %% [markdown]
# ### Cálculo de probabilidades:
# $\mathbb{P}(0<Z<b)$: Queremos calcular $\mathbb{P}(0<Z<0.43)$, lo cuál puede realizarse de la siguiente manera:
# * Tablas de área a la derecha: $\mathbb{P}(0<Z<0.43) = 0.1664$

# %%
from scipy.stats import norm
prob1=norm(0,1).cdf(0.43)-norm(0,1).cdf(0)
print(" La probabilidad de calcular P(0 < Z < 0.43) es:", round(prob1,4))
# Out:
#  La probabilidad de calcular P(0 < Z < 0.43) es: 0.1664

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
# for distribution curve
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x,loc=0,scale=1))
ax.set_title("N(0,$1^2$)")
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
px=np.arange(0,0.43,0.01)
ax.set_ylim(0,0.45)
ax.fill_between(px,norm.pdf(px,loc=0,scale=1),alpha=0.5, color='g')
pro=prob1
ax.text(0.2,0.02,round(pro,4), fontsize=20)
plt.show()

# %% [markdown]
# $\mathbb{P}(-b<Z<b)$: Queremos calcular $\mathbb{P}(-0.16<Z<0.16)$, lo cuál puede realizarse de la siguiente manera:
# * Tablas de área a la derecha:  $\mathbb{P}(-0.16<Z<0.16) = \mathbb{P}(-0.16<Z<0)+\mathbb{P} (0<Z<0.16) = \mathbb{P}(0<Z<0.16)+\mathbb{P}(0<Z<0.16) = 2\mathbb{P}(0<Z<0.16) = 2(0.0636) = 0.1272$

# %%
prob2=norm(0,1).cdf(0.16)-norm(0,1).cdf(-0.16)
print(" La probabilidad de calcular P(-0.16 < Z < 0.16) es:", round(prob2,4))
# Out:
#  La probabilidad de calcular P(-0.16 < Z < 0.16) es: 0.1271

# %%
fig, ax = plt.subplots()
# for distribution curve
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x,loc=0,scale=1))
ax.set_title("N(0,$1^2$)")
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
px=np.arange(-0.16,0.16,0.01)
ax.set_ylim(0,0.45)
ax.fill_between(px,norm.pdf(px,loc=0,scale=1),alpha=0.5, color='g')
pro=prob2
ax.text(0.2,0.02,round(pro,4), fontsize=20)
plt.show()

# %% [markdown]
# $\mathbb{P}(Z<-b)$: Queremos calcular $\mathbb{P}(Z<-1.94)$, lo cuál puede realizarse de la siguiente manera:
# * Tablas de área a la derecha: $\mathbb{P}(Z<-1.94) = \mathbb{P}(Z<0)+\mathbb{P}(-1.94<Z<0) = \mathbb{P}(Z<0) + \mathbb{P}(0<Z<1.94) = 0.5 - 0.4738 = 0.0262$

# %%
prob3=norm(0,1).cdf(-1.94)
print(" La probabilidad de calcular P(Z < -1.94) es:", round(prob3,4))
# Out:
#  La probabilidad de calcular P(Z < -1.94) es: 0.0262

# %%
fig, ax = plt.subplots()
# for distribution curve
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x,loc=0,scale=1))
ax.set_title("N(0,$1^2$)")
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
px=np.arange(-3,-1.94,0.01)
ax.set_ylim(0,0.45)
ax.fill_between(px,norm.pdf(px,loc=0,scale=1),alpha=0.5, color='g')
pro=prob3
ax.text(0.2,0.02,round(pro,4), fontsize=20)
plt.show()

# %% [markdown]
# $\mathbb{P}(Z>-b)$: Queremos calcular $(Z>-0.07)$, lo cuál puede realizarse de la siguiente manera:
# * Tablas de área a la derecha: $\mathbb{P}(Z>-0.07) = \mathbb{P}(-0.07<Z<0) + \mathbb{P}(Z>0) = \mathbb{P}(0<Z<0.07) + \mathbb{P}(Z>0) = 0.0279 + 0.5 = 0.5279$

# %%
prob4=1-norm(0,1).cdf(-0.07)
print(" La probabilidad de calcular P(Z > -0.07) es:", round(prob4,4))
# Out:
#  La probabilidad de calcular P(Z > -0.07) es: 0.5279

# %%
fig, ax = plt.subplots()
# for distribution curve
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x,loc=0,scale=1))
ax.set_title("N(0,$1^2$)")
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
px=np.arange(-0.07,3,0.01)
ax.set_ylim(0,0.45)
ax.fill_between(px,norm.pdf(px,loc=0,scale=1),alpha=0.5, color='g')
pro=prob4
ax.text(0.2,0.02,round(pro,4), fontsize=20)
plt.show()
